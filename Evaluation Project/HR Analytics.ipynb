# %% [markdown]
# # HR Analytics

# %%
#importing important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#importing csv file
df=pd.read_csv("HR-Employee-Attrition.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# # EDA

# %%
#checking null data in column
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#Checking Statistics data
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#Information about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#Data Seperated based on data type
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {dtype('int64'): Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#         'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#         'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#         'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#         'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#         'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#         'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#         'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#        dtype='object'),
#  dtype('O'): Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#         'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#        dtype='object')}

# %% [markdown]
# The above Output shows continuous and categorical data.

# %%
#Unique values of Categorical Data
cat_data=['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
        'JobRole', 'MaritalStatus', 'Over18', 'OverTime']
for i in cat_data:
    print(i,":",df[i].unique())
    print(i,":",df[i].nunique())
    print(df[i].value_counts())
    print('----------------------------------------------------------')
# Out:
# Attrition : ['Yes' 'No']
# Attrition : 2
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# ----------------------------------------------------------
# BusinessTravel : ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# BusinessTravel : 3
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# ----------------------------------------------------------
# Department : ['Sales' 'Research & Development' 'Human Resources']
# Department : 3
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# ----------------------------------------------------------
# EducationField : ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# EducationField : 6
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# ...

# %% [markdown]
# Above shows the unique values of categorical data.

# %% [markdown]
# # Visualization

# %%
#Using histogram to check normal distribution
df.hist(figsize=(20,20),grid=True,bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002508C5D4C40>,
# ...
#       dtype=object)

# %% [markdown]
# From the above histograms DistanceFromHome, MonthlyIncome and YearsAtCompany are right skewed.
# Employee Number is unique for each employee.
# EmployeeCount and StandardHours are same for all employees.

# %%
sns.countplot(df['Attrition'])

# %% [markdown]
# The above plot visualize the attrition count.

# %%
#Target variable value count.
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
#Calculating percentage of attrition
(1233-237)/1233*100
# Out:
# 80.7785888077859

# %%
#visualization of attrition based on age
plt.figure(figsize=(15,5))
sns.countplot(x='Age',hue='Attrition',data=df)

# %% [markdown]
# Above Visualization shows that 34 & 35 age employee has maximum active employee and 29 & 31 age has maximum ex-employees.

# %%
#visualization of attrition based on Gender
sns.countplot(x='Gender',hue='Attrition',data=df)

# %% [markdown]
# Above visualization shows that male has more ex-employees than female, and male has more active employees than female.

# %%
['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
        'JobRole', 'MaritalStatus', 'Over18', 'OverTime']
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'Over18',
#  'OverTime']

# %%
#visualization of attrition based on Business Travel
sns.countplot(x='BusinessTravel',hue='Attrition',data=df)

# %% [markdown]
# Above visualization shows that those who travel rarely has maximum active employees and ex-employees

# %%
#visualization of attrition based on Department
sns.countplot(x='Department',hue='Attrition',data=df)

# %% [markdown]
# Above visualization shows that those who are in Research & Development Department has maximum active employees and ex-employees.

# %%
#visualization of attrition based on EducationField
sns.countplot(x='EducationField',hue='Attrition',data=df)

# %% [markdown]
# Above visualization shows that those who are from Life Sciences field has maximum active employees and ex-employees.

# %%
#visualization of attrition based on Job Role
plt.figure(figsize=(20,4))
sns.countplot(x='JobRole',hue='Attrition',data=df)

# %% [markdown]
# Above visualization shows that Laboratory Technician has maximum ex-employees and Sales Executive has maximum active employees.

# %%
#visualization of attrition based on Martial Status
sns.countplot(x='MaritalStatus',hue='Attrition',data=df)

# %% [markdown]
# Above visualization shows that Single shows largest proportion of ex-employees.

# %%
#visualization of attrition based on Over Time
sns.countplot(x='OverTime',hue='Attrition',data=df)

# %% [markdown]
# Above visualization shows that there is larger portion of employees with OT that have left the company.

# %%
#Removing constant value columns from dataframe
df.drop(['EmployeeCount','EmployeeNumber','StandardHours','Over18'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
#Changing column position
df=df[['Age', 'BusinessTravel', 'DailyRate', 'Department',
       'DistanceFromHome', 'Education', 'EducationField',
       'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
       'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
       'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
       'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
       'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
       'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager', 'Attrition']]

# %%
#correlation
corr=df.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corr, annot=True)

# %% [markdown]
# # Label Encoding

# %%
#Transforming categorical data into numerical data
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
cols=['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
        'JobRole', 'MaritalStatus', 'OverTime']
for col in cols:
    df[col]=encoder.fit_transform(df[col].astype(str))
    
df.dtypes
# Out:
# Age                         int64
# BusinessTravel              int32
# DailyRate                   int64
# Department                  int32
# DistanceFromHome            int64
# Education                   int64
# EducationField              int32
# EnvironmentSatisfaction     int64
# Gender                      int32
# HourlyRate                  int64
# JobInvolvement              int64
# JobLevel                    int64
# JobRole                     int32
# JobSatisfaction             int64
# MaritalStatus               int32
# MonthlyIncome               int64
# MonthlyRate                 int64
# NumCompaniesWorked          int64
# OverTime                    int32
# PercentSalaryHike           int64
# PerformanceRating           int64
# RelationshipSatisfaction    int64
# StockOptionLevel            int64
# TotalWorkingYears           int64
# TrainingTimesLastYear       int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# ...

# %%
df.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   41               2       1102           2                 1          2
# 1   49               1        279           1                 8          1
# 2   37               2       1373           1                 2          2
# 3   33               1       1392           1                 3          4
# 4   27               2        591           1                 2          1
#
#    EducationField  EnvironmentSatisfaction  Gender  HourlyRate  ...  \
# 0               1                        2       0          94  ...
# 1               1                        3       1          61  ...
# 2               4                        4       1          92  ...
# 3               1                        4       0          56  ...
# 4               3                        1       1          40  ...
#
#    RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# ...

# %%
#Re-Checking correlation
corr=df.corr()
plt.figure(figsize=(25,20))
sns.heatmap(corr, annot=True)

# %% [markdown]
# # Outliers

# %%
#Using boxplot to check ouliers
col_box=['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EnvironmentSatisfaction', 'HourlyRate',
        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
        'PerformanceRating', 'RelationshipSatisfaction',
        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
        'YearsSinceLastPromotion', 'YearsWithCurrManager']
df[col_box].plot(figsize=(20,25),kind='box',layout=(9,3),subplots=True)
# Out:
# Age                            AxesSubplot(0.125,0.808774;0.227941x0.0712264)
# DailyRate                   AxesSubplot(0.398529,0.808774;0.227941x0.0712264)
# DistanceFromHome            AxesSubplot(0.672059,0.808774;0.227941x0.0712264)
# Education                      AxesSubplot(0.125,0.723302;0.227941x0.0712264)
# EnvironmentSatisfaction     AxesSubplot(0.398529,0.723302;0.227941x0.0712264)
# HourlyRate                  AxesSubplot(0.672059,0.723302;0.227941x0.0712264)
# JobInvolvement                  AxesSubplot(0.125,0.63783;0.227941x0.0712264)
# JobLevel                     AxesSubplot(0.398529,0.63783;0.227941x0.0712264)
# JobSatisfaction              AxesSubplot(0.672059,0.63783;0.227941x0.0712264)
# MonthlyIncome                  AxesSubplot(0.125,0.552358;0.227941x0.0712264)
# MonthlyRate                 AxesSubplot(0.398529,0.552358;0.227941x0.0712264)
# NumCompaniesWorked          AxesSubplot(0.672059,0.552358;0.227941x0.0712264)
# ...

# %% [markdown]
# Above box plot shows Monthly Income, Total Working Hours, Years At Company, Years Since Last Promotion, Years In Current Role has more outliers.

# %%
#Removing ouliers using zscore
from scipy.stats import zscore
z=np.abs(zscore(df))
threshold=3
new_df=df[(z<3).all(axis=1)]
print(df.shape)
print(new_df.shape)
# Out:
# (1470, 31)
# (1387, 31)

# %%
#Checking skewness
new_df.skew()
# Out:
# Age                         0.472280
# BusinessTravel             -1.426774
# DailyRate                  -0.017078
# Department                  0.183919
# DistanceFromHome            0.954752
# Education                  -0.289024
# EducationField              0.544868
# EnvironmentSatisfaction    -0.325285
# Gender                     -0.417296
# HourlyRate                 -0.030481
# JobInvolvement             -0.501401
# JobLevel                    1.126075
# JobRole                    -0.386843
# JobSatisfaction            -0.345612
# MaritalStatus              -0.160952
# MonthlyIncome               1.544770
# MonthlyRate                 0.030596
# NumCompaniesWorked          1.037715
# OverTime                    0.954751
# PercentSalaryHike           0.800592
# PerformanceRating           1.931566
# RelationshipSatisfaction   -0.295686
# StockOptionLevel            0.962332
# TotalWorkingYears           1.034487
# TrainingTimesLastYear       0.577614
# ...

# %%
#Reducing Skewness using log method
skew=('BusinessTravel','Department', 'DistanceFromHome', 'JobLevel', 'MonthlyIncome', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'StockOptionLevel', 'TotalWorkingYears', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager')
for col in skew :
    if new_df.skew().loc[col]>0.55:
        new_df[col] = np.log1p(new_df[col])

# %%
#Re-Checking skewness
new_df.skew()
# Out:
# Age                         0.472280
# BusinessTravel             -1.426774
# DailyRate                  -0.017078
# Department                  0.183919
# DistanceFromHome           -0.031570
# Education                  -0.289024
# EducationField              0.544868
# EnvironmentSatisfaction    -0.325285
# Gender                     -0.417296
# HourlyRate                 -0.030481
# JobInvolvement             -0.501401
# JobLevel                    0.497167
# JobRole                    -0.386843
# JobSatisfaction            -0.345612
# MaritalStatus              -0.160952
# MonthlyIncome               0.318873
# MonthlyRate                 0.030596
# NumCompaniesWorked          0.101288
# OverTime                    0.954751
# PercentSalaryHike           0.496106
# PerformanceRating           1.931566
# RelationshipSatisfaction   -0.295686
# StockOptionLevel            0.275912
# TotalWorkingYears          -0.728348
# TrainingTimesLastYear       0.577614
# ...

# %% [markdown]
# # Scaling

# %%
#Assigning input and target data
X=new_df.drop(['Attrition'],axis=1)
Y=new_df[['Attrition']]

# %%
#Scaling data using Standard Scaler
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
ScaledX=sc.fit_transform(X)

# %% [markdown]
# # Models

# %%
#importing imporant libraries for models
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.model_selection import cross_val_score, train_test_split

# %%
#Finding best model and random state
best_rstate_clas=0
best_accu_rate=0
models=[RandomForestClassifier(), LogisticRegression(), AdaBoostClassifier(), 
       GradientBoostingClassifier(), DecisionTreeClassifier(), SVC(), KNeighborsClassifier()]
for r in range(1,200):
    x_train, x_test, y_train, y_test=train_test_split(ScaledX,Y,test_size=0.33,random_state=r)
    for model in models:
        model.fit(x_train,y_train.values.ravel())
        pred_test=model.predict(x_test)
        pred_train=model.predict(x_train)
        #accu_score=accuracy_score(y_test,model_pred)
        if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
            print("best random state",r)
            print("At random state",r)
            print("Training score :",accuracy_score(y_train,pred_train)*100)
            print("Testing score :",accuracy_score(y_test,pred_test)*100)
            print("Model : ", model)
# Out:
# best random state 32
# At random state 32
# Training score : 88.58988159311087
# Testing score : 88.64628820960698
# Model :  LogisticRegression()
# best random state 186
# At random state 186
# Training score : 87.83638320775027
# Testing score : 87.77292576419214
# Model :  LogisticRegression()

# %% [markdown]
# Logistic Regression is best model.

# %%
from sklearn.model_selection import GridSearchCV
LR=LogisticRegression(max_iter=200)
x_train, x_test, y_train, y_test=train_test_split(ScaledX,Y,test_size=0.33,random_state=32)
grid_values = {'penalty': ['l1','l2'], 'C': [0.001,0.01,0.1,1,10,100,1000]}
gridsearch_LR=GridSearchCV(LR,grid_values)
gridsearch_LR.fit(x_train,y_train)
pred_LR=gridsearch_LR.predict(x_test)
LR_best_parm=gridsearch_LR.best_params_
print("Best Param ",gridsearch_LR.best_params_)
print("Best estimator ",gridsearch_LR.best_estimator_)
print("Best score ",gridsearch_LR.best_score_)
# Out:
# Best Param  {'C': 0.1, 'penalty': 'l2'}
# Best estimator  LogisticRegression(C=0.1, max_iter=200)
# Best score  0.8751351351351351

# %%
#Finding best CV core and accuracy score
LR=LogisticRegression(C=0.1, max_iter=200)
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
lss=accuracy_score(y_test,pred_LR)
for j in range(2,20):
    lssscore=cross_val_score(LR,ScaledX,Y,cv=j)
    lsc=lssscore.mean()
    print("At CV : ",j)
    print("cross validation score is :",lsc*100)
    print("accuracy_score is :",lss*100)
    print('\n')
# Out:
# At CV :  2
# cross validation score is : 87.09397390953586
# accuracy_score is : 89.08296943231441
#
#
# At CV :  3
# cross validation score is : 87.67122006862827
# accuracy_score is : 89.08296943231441
#
#
# At CV :  4
# cross validation score is : 87.23950958671352
# accuracy_score is : 89.08296943231441
#
#
# At CV :  5
# cross validation score is : 87.52798483235074
# accuracy_score is : 89.08296943231441
#
#
# At CV :  6
# cross validation score is : 87.4542842215256
# accuracy_score is : 89.08296943231441
#
#
# At CV :  7
# cross validation score is : 87.88603914232056
# accuracy_score is : 89.08296943231441
#
#
# At CV :  8
# cross validation score is : 87.81559364826256
# accuracy_score is : 89.08296943231441
#
#
# At CV :  9
# cross validation score is : 87.6697854117209
# accuracy_score is : 89.08296943231441
#
#
# At CV :  10
# cross validation score is : 87.6024397873006
# accuracy_score is : 89.08296943231441
#
#
# At CV :  11
# ...

# %%
#Classification Report
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_LR))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       389
#            1       0.81      0.36      0.50        69
#
#     accuracy                           0.89       458
#    macro avg       0.85      0.67      0.72       458
# weighted avg       0.88      0.89      0.87       458

# %%
#Final CV score and accuracy score
lssscore_selected=cross_val_score(LR,ScaledX,Y,cv=18).mean()
print("The CV score is",lssscore_selected," \nThe accuracy score is",lss)
# Out:
# The CV score is 0.8802956302956303
# The accuracy score is 0.8908296943231441

# %%
#Roc curve
from sklearn.metrics import roc_curve, auc
fpr,tpr,thresholds=roc_curve(y_test, pred_LR)
roc_auc=auc(fpr,tpr)
plt.figure
plt.plot(fpr,tpr,color='darkorange',lw=10,label='ROC curve (area=%0.2f)'%roc_auc)
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Random Forest Classifier

# %%
#Classifying data to check which data impact attrition
from sklearn.ensemble import RandomForestClassifier
RFC=RandomForestClassifier(bootstrap=True, class_weight='balanced',
            criterion='gini', max_depth=15, max_features='auto',
            max_leaf_nodes=None, min_impurity_decrease=0.0,
            min_impurity_split=None, min_samples_leaf=1,
            min_samples_split=8, min_weight_fraction_leaf=0.0,
            n_estimators=75, n_jobs=None, oob_score=False, random_state=7,
            verbose=0, warm_start=False)

RFC.fit(x_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=15,
#                        min_samples_split=8, n_estimators=75, random_state=7)

# %%
features_label = new_df.columns[:-1]

# %%
RFC_Feature= RFC.feature_importances_
indices = np.argsort(RFC_Feature)[::-1]
names = [features_label[i] for i in indices] 
plt.figure(figsize=(15, 7))
plt.title("Feature Importance")
plt.bar(range(x_train.shape[1]), RFC_Feature[indices])
plt.xticks(range(x_train.shape[1]), names, rotation=90)
plt.show()

# %% [markdown]
# Above visualisation shows
# Random Forest helped us identify the Top most important indicators, where monthly income with higher wages are less likely to leave the company.

# %% [markdown]
# # Saving Model

# %%
#save the model 
import pickle
filename='HR.pkl'
pickle.dump(LR,open(filename,'wb'))

# %% [markdown]
# # Conclusion

# %% [markdown]
# we saw Data is important in Human Resource department(actually in most of places it is important).
# In this project, I used Machine Learning to predict whether a person is leaving a company or not.
# After importing the data, I did EDA process and removed unwanted data.
# I analysed data using plots.
# Removed outliers using zscore method and Scaled data using Standard Scaler.
# Used Machine Learning algorithms, RandomForestClassifier, LogisticRegression, AdaBoostClassifier, GradientBoostingClassifier, DecisionTreeClassifier, SVC, KNeighborsClassifier.
# Logistic Regression is the best model and scores are:
#
# CV score is 0.8802956302956303
# Accuracy score is 0.8908296943231441,
# ROC Curve Score is 67.
#
# Random Classifier shows indicators(data) of employee leaving company:
# We saw how we can avoid using correlated values and why it is important not to use those while modelling.
# We used Random forest and learned how it can be very advantageous over other available machine learning algorithm.
# Most of all we found factors which are most important to employees and if are not fulfilled might lead to Attrition.
# One of the best feature Random forest model has it provides the importance of variables/features in the data/model.
# For this HR Analytics problem, we are interested in knowing which feature/factor contribute the most in the Attrition.
